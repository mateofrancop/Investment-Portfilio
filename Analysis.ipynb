# %%
# Importing the libraries


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\Alvaro\OneDrive\Documentos\Primer proyecto\codigo\Financial_proyect\Data\Data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      251 non-null    datetime64[ns]
#  1   APPLE     251 non-null    float64
#  2   MICROFT   251 non-null    float64
#  3   GOOGLE    251 non-null    float64
#  4   NVIDIA    251 non-null    float64
#  5   NIKE      251 non-null    float64
#  6   NASDAQ    251 non-null    float64
#  7   S&P 500   251 non-null    float64
#  8   PETROLEO  251 non-null    float64
#  9   ORO       251 non-null    float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 19.7 KB

# %%
df
# Out:
#           Date       APPLE     MICROFT      GOOGLE      NVIDIA       NIKE  \
# 0   2022-10-06  145.429993  246.789993  102.239998  120.760002  90.169998
# 1   2022-10-07  140.089996  234.240005   99.570000  116.699997  87.160004
# 2   2022-10-10  140.419998  229.250000   98.709999  115.860001  86.690002
# 3   2022-10-11  138.979996  225.410004   98.050003  115.000000  87.989998
# 4   2022-10-12  138.339996  225.750000   98.300003  119.599998  88.510002
# ..         ...         ...         ...         ...         ...        ...
# 246 2023-09-29  171.210007  315.750000  131.850006  447.820007  95.620003
# 247 2023-10-02  173.750000  321.799988  135.169998  435.170013  94.559998
# 248 2023-10-03  172.399994  313.390015  133.300003  440.410004  95.089996
# 249 2023-10-04  173.660004  318.959991  136.270004  446.880005  95.889999
# 250 2023-10-05  174.910004  319.359985  135.990005  455.520111  95.790001
#
#            NASDAQ  S&P 500  PETROLEO      ORO
# ...

# %%
# Filter only the numeric columns
df_numeric = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = df_numeric.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Mapa de Calor de Correlación')
plt.show()

# %%
# Create the scatter plot
sns.set(style="whitegrid")  
plt.figure(figsize=(8, 6))  
sns.scatterplot(x="PETROLEO", y="ORO", data=df, marker="o", color="blue", label="Datos")
plt.xlabel('Petróleo')
plt.ylabel('Oro')
plt.title('Relación entre Petróleo y Oro')
plt.legend()
plt.show()

# %%
# Create the scatter plot
sns.set(style="whitegrid")  
plt.figure(figsize=(8, 6))  
sns.scatterplot(x="APPLE", y="MICROFT", data=df, marker="o", color="blue", label="Datos")
plt.xlabel('Apple')
plt.ylabel('Microsoft')
plt.title('Relación entre Apple y Microsoft')
plt.legend()
plt.show()

# %%
# Create the scatter plot
sns.set(style="whitegrid")  
plt.figure(figsize=(8, 6))  
sns.scatterplot(x="NASDAQ", y="S&P 500", data=df, marker="o", color="blue", label="Datos")
plt.xlabel('Nasdaq')
plt.ylabel('S&P 500')
plt.title('Relación entre Nasdaq y S&P 500')
plt.legend()
plt.show()

# %%
# Create the scatter plot
sns.set(style="whitegrid")  
plt.figure(figsize=(8, 6))  
sns.scatterplot(x="PETROLEO", y="NIKE", data=df, marker="o", color="blue", label="Datos")
plt.xlabel('Petróleo')
plt.ylabel('Nike')
plt.title('Relación entre Petróleo y Nike')
plt.legend()
plt.show()

# %%
# Calculate daily percentage performance for each closing column
for col in df.columns:
    if col != "Date" and col != "Rendimiento Total":
        df[col + "_Rendimiento (%)"] = (df[col] / df[col].iloc[0] - 1) * 100

# Set the figure size
plt.figure(figsize=(10, 6))

# Iterate through the performance columns and create a line for each one
for col in df.columns:
    if "_Rendimiento (%)" in col:
        sns.lineplot(x="Date", y=col, data=df, label=col)

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Rendimiento (%)")
plt.title("Comparación de Rendimiento de Activos en Porcentaje")
plt.grid(True)

# Show the plot without legend
plt.legend()

# Show the plot
plt.show()

# %%
# Calculate cumulative total performance
df["Rendimiento Total"] = (df["PETROLEO"] / df["PETROLEO"].iloc[0] - 1) * 100

# Create a total performance chart with Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x="Date", y="Rendimiento Total", data=df, marker="o", color="blue")
plt.xlabel("Date")
plt.ylabel("Rendimiento Total (%)")
plt.title("Gráfico de Rendimiento Total del Petroleo")
plt.grid(True)

# Show the chart
plt.show()

# %%
# Calculate cumulative total performance
df["Rendimiento Total"] = (df["NVIDIA"] / df["NVIDIA"].iloc[0] - 1) * 100


# Create a total performance chart using Seaborn

plt.figure(figsize=(10, 6))
sns.lineplot(x="Date", y="Rendimiento Total", data=df, marker="o", color="blue")
plt.xlabel("Date")
plt.ylabel("Rendimiento Total (%)")
plt.title("Gráfico de Rendimiento Total de NVIDIA")
plt.grid(True)

# Display the chart
plt.show()

# %%
# Calculate cumulative total performance
df["Rendimiento Total"] = (df["NASDAQ"] / df["NASDAQ"].iloc[0] - 1) * 100

# Create a total performance chart using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x="Date", y="Rendimiento Total", data=df, marker="o", color="blue")
plt.xlabel("Date")
plt.ylabel("Rendimiento Total (%)")
plt.title("Gráfico de Rendimiento Total del NASDAQ")
plt.grid(True)

# Display the chart
plt.show()

# %%
# Calculate cumulative total performance
df["Rendimiento Total"] = (df["S&P 500"] / df["S&P 500"].iloc[0] - 1) * 100

# Create a total performance chart using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x="Date", y="Rendimiento Total", data=df, marker="o", color="blue")
plt.xlabel("Date")
plt.ylabel("Rendimiento Total (%)")
plt.title("Gráfico de Rendimiento Total del S&P 500")
plt.grid(True)

# Display the chart
plt.show()

# %%
# Calculate daily percentage returns for all closing columns
for col in df.columns:
    if col != "Date" and col != "S&P 500":
        df[col + "_Rendimiento (%)"] = ((df[col] / df[col].shift(1)) - 1) * 100

# Calculate S&P 500 percentage returns
df["S&P 500_Rendimiento (%)"] = ((df["S&P 500"] / df["S&P 500"].shift(1)) - 1) * 100

# Set the figure size
plt.figure(figsize=(10, 6))

# Iterate through financial asset return columns and create a line for each
for col in df.columns:
    if "_Rendimiento (%)" in col:
        rendimiento_relativo = (df[col] - df["S&P 500_Rendimiento (%)"])
        sns.lineplot(x="Date", y=rendimiento_relativo, label=col, data=df)

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Rendimiento Relativo al S&P 500 (%)")
plt.title("Gráfico de Rendimiento Relativo al S&P 500 (Diario)")
plt.grid(True)

# Add a legend
plt.legend()

# Display the chart
plt.show()

# %%
# Calculate Nasdaq percentage returns
df["NASDAQ_Rendimiento (%)"] = ((df["NASDAQ"] / df["NASDAQ"].iloc[0] - 1)) * 100

# Calculate S&P 500 percentage returns
df["S&P 500_Rendimiento (%)"] = ((df["S&P 500"] / df["S&P 500"].iloc[0] - 1)) * 100

# Set the figure size
plt.figure(figsize=(10, 6))

# Iterate through financial asset return columns and create a line for each
rendimiento_relativo = (df["NASDAQ_Rendimiento (%)"] - df["S&P 500_Rendimiento (%)"])
sns.lineplot(x="Date", y=rendimiento_relativo, label="NASDAQ_Rendimiento (%)", data=df)

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Rendimiento Relativo al S&P 500 (%)")
plt.title("Gráfico de Rendimiento Relativo al S&P 500 (NASDAQ)")
plt.grid(True)

# Add a legend
plt.legend()

# Display the chart
plt.show()

# %%
# Calculate Nike percentage returns
df["NIKE_Rendimiento (%)"] = ((df["NIKE"] / df["NIKE"].iloc[0] - 1)) * 100

# Calculate S&P 500 percentage returns
df["S&P 500_Rendimiento (%)"] = ((df["S&P 500"] / df["S&P 500"].iloc[0] - 1)) * 100

# Set the figure size
plt.figure(figsize=(10, 6))

# Iterate through financial asset return columns and create a line for each
rendimiento_relativo = (df["NIKE_Rendimiento (%)"] - df["S&P 500_Rendimiento (%)"])
sns.lineplot(x="Date", y=rendimiento_relativo, label="NIKE_Rendimiento (%)", data=df)

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Rendimiento Relativo al S&P 500 (%)")
plt.title("Gráfico de Rendimiento Relativo al S&P 500 (NIKE)")
plt.grid(True)

# Add a legend
plt.legend()

# Display the chart
plt.show()

# %%
# Calculate Microsoft percentage returns
df["MICROFT_Rendimiento (%)"] = ((df["MICROFT"] / df["MICROFT"].iloc[0] - 1)) * 100

# Calculate NASDAQ percentage returns
df["NASDAQ_Rendimiento (%)"] = ((df["NASDAQ"] / df["NASDAQ"].iloc[0] - 1)) * 100

# Set the figure size
plt.figure(figsize=(10, 6))

# Iterate through financial asset return columns and create a line for each
rendimiento_relativo = (df["MICROFT_Rendimiento (%)"] - df["NASDAQ_Rendimiento (%)"])
sns.lineplot(x="Date", y=rendimiento_relativo, label="MICROFT_Rendimiento (%)", data=df)

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Rendimiento Relativo al NASDAQ (%)")
plt.title("Gráfico de Rendimiento Relativo al NASDAQ (MICROSOFT)")
plt.grid(True)

# Add a legend
plt.legend()

# Display the chart
plt.show()

# %%
# Calculate daily percentage returns for the financial asset's closing column
df["Rendimiento Diario (%)"] = ((df["APPLE"] / df["APPLE"].shift(1)) - 1) * 100

# Set the Seaborn style (optional)
sns.set(style="whitegrid")

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram of daily returns using Seaborn
sns.histplot(data=df, x="Rendimiento Diario (%)", bins=30, kde=True)

# Customize the plot
plt.xlabel("Rendimiento Diario (%)")
plt.ylabel("Frecuencia")
plt.title("Histograma de Rendimientos Diarios de APPLE")
plt.grid(True)

# Display the chart
plt.show()

# %%
# Calculate daily percentage returns for the financial asset's closing column
df["Rendimiento Diario (%)"] = ((df["NVIDIA"] / df["NVIDIA"].shift(1)) - 1) * 100

# Set the Seaborn style (optional)
sns.set(style="whitegrid")

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram of daily returns using Seaborn
sns.histplot(data=df, x="Rendimiento Diario (%)", bins=30, kde=True)

# Customize the plot
plt.xlabel("Rendimiento Diario (%)")
plt.ylabel("Frecuencia")
plt.title("Histograma de Rendimientos Diarios de NVIDIA")
plt.grid(True)

# Display the chart
plt.show()

# %%
# Calculate daily percentage returns for the financial asset's closing column
df["Rendimiento Diario (%)"] = ((df["ORO"] / df["ORO"].shift(1)) - 1) * 100

# Set the Seaborn style (optional)
sns.set(style="whitegrid")

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram of daily returns using Seaborn
sns.histplot(data=df, x="Rendimiento Diario (%)", bins=30, kde=True)

# Customize the plot
plt.xlabel("Rendimiento Diario (%)")
plt.ylabel("Frecuencia")
plt.title("Histograma de Rendimientos Diarios de ORO")
plt.grid(True)

# Display the chart
plt.show()

# %%
# Calculate daily percentage returns for the closing columns of financial assets
for col in df.columns:
    if col != "Date" and col != "S&P 500" and col != "NASDAQ":
        df[col + "_Rendimiento Diario (%)"] = ((df[col] / df[col].shift(1)) - 1) * 100

# Create a DataFrame with daily returns
df_rendimientos_diarios = df[[col for col in df.columns if "Rendimiento Diario" in col]]

# Set the Seaborn style (optional)
sns.set(style="whitegrid")

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram of daily returns using Seaborn
sns.histplot(data=df_rendimientos_diarios, bins=30, kde=True)

# Customize the plot
plt.xlabel("Rendimiento Diario (%)")
plt.ylabel("Frecuencia")
plt.title("Histograma de Rendimientos Diarios")
plt.grid(True)

# Display the chart
plt.show()
